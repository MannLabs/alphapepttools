# %% [markdown]
# ### Notebook to recreate test data for tests/tl

# %%
# # data for tl/test_diff_exp_alphaquant

# import numpy as np
# import anndata as ad
# import pandas as pd
# from alphatools import tl

# alphaquant_small_report = "https://datashare.biochem.mpg.de/s/9RPgEtHH3b3iE2b/download"
# report = pd.read_csv(alphaquant_small_report, sep="\t")

# alphaquant_samplemap_link = "https://datashare.biochem.mpg.de/s/weKAg5QGRcjoP8j/download"
# samplemap = pd.read_csv(alphaquant_samplemap_link, sep="\t")

# adata = ad.AnnData(
#     X = pd.DataFrame(np.zeros(samplemap.shape[0]), index=samplemap['sample'], columns=['dummy']),
#     obs = samplemap.set_index('sample')
# )

# comparison_key, results = tl.diff_exp_alphaquant(
#     adata = adata,
#     report = report,
#     between_column = "condition",
#     comparison = ("brain", "kidney"),
#     min_valid_values = 2,
#     valid_values_filter_mode = "either",
#     plots = "hide",
# )

# results['protein'].to_pickle("./tl_test_data/alphaquant_protein_diffexp.pkl")
# results['proteoform'].to_pickle("./tl_test_data/alphaquant_proteoform_diffexp.pkl")
# results['peptide'].to_pickle("./tl_test_data/alphaquant_peptide_diffexp.pkl")
# Out:
# INFO:alphatools.tl.utils:Number of samples for brain: 10
# INFO:alphatools.tl.utils:Number of samples for kidney: 10
# INFO:alphaquant.run_pipeline:Starting AlphaQuant
# /Users/vincenthbrennsteiner/Documents/mann_labs/_git_repositories/alphabase/alphabase/quantification/quant_reader/table_reformatter.py:75: FutureWarning: Downcasting object dtype arrays on .fillna, .ffill, .bfill is deprecated and will change in a future version. Call result.infer_objects(copy=False) instead. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   return df[columns[0]].fillna("nan").infer_objects(copy=False).astype(str)
# INFO:alphaquant.diffquant.condpair_analysis:start processeing condpair ('brain', 'kidney')
# INFO:alphaquant.norm.normalization:normalized within conditions
# INFO:alphaquant.plotting.pairwise:without missingvals (if applicable)
# INFO:alphaquant.plotting.pairwise:complete dataset
# using input type spectronaut_fragion_ms1_gene
# ...
