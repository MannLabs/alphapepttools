# %%
# %load_ext autoreload
# %autoreload 2

# %%
import logging
import os

from data_handler import DataHandler

import alphatools as at
from alphatools.pl.figure import create_figure, label_axes
from alphatools.pl.plots import Plots

logging.basicConfig(level=logging.INFO)
_is_pytest_run = os.environ.get("IS_PYTEST_RUN", "False").lower() == "true"
# Out:
# INFO:rdkit:Enabling RDKit 2024.03.3 jupyter extensions
# /Users/vincenthbrennsteiner/miniconda3/envs/alphaverse/lib/python3.11/site-packages/alphabase/tools/data_downloader.py:4: DeprecationWarning: 'cgi' is deprecated and slated for removal in Python 3.13
#   import cgi

# %% [markdown]
# ## Basic EDA on a 'real life' example dataset:
#
# 1. Download example data
# 2. Filter for data completeness on sample level
# 3. Visualize samples as histograms
# 4. Save data

# %%
output_directory = "./example_outputs/03b_basic_workflow/"

# %% [markdown]
# ### Generate an example dataset as an anndata.AnnData instance

# %%
data_handler = DataHandler("domap", target_folder="HOME")

adata = data_handler.get_data("adata", truncate=_is_pytest_run)

df_metadata = data_handler.get_data("metadata")
adata = at.pp.add_metadata(adata, df_metadata.set_index("filename"), axis=0, keep_existing_metadata=_is_pytest_run)

print("The numeric data in the anndata object:")
display(adata.to_df().head())

print("The sample-level metadata in the anndata object:")
display(adata.obs.head())

print("The feature-level metadata in the anndata object:")
display(adata.var.head())
# Out:
# /Users/vincenthbrennsteiner/miniconda3/envs/alphaverse/lib/python3.11/site-packages/debugpy/_vendored/pydevd/pydev_ipython/matplotlibtools.py:59: MatplotlibDeprecationWarning: The interactive_bk attribute was deprecated in Matplotlib 3.9 and will be removed in 3.11. Use ``matplotlib.backends.backend_registry.list_builtin(matplotlib.backends.BackendFilter.INTERACTIVE)`` instead.
#   from matplotlib.rcsetup import interactive_bk, non_interactive_bk  # @UnresolvedImport
# /Users/vincenthbrennsteiner/miniconda3/envs/alphaverse/lib/python3.11/site-packages/debugpy/_vendored/pydevd/pydev_ipython/matplotlibtools.py:59: MatplotlibDeprecationWarning: The non_interactive_bk attribute was deprecated in Matplotlib 3.9 and will be removed in 3.11. Use ``matplotlib.backends.backend_registry.list_builtin(matplotlib.backends.BackendFilter.NON_INTERACTIVE)`` instead.
#   from matplotlib.rcsetup import interactive_bk, non_interactive_bk  # @UnresolvedImport
# /Users/vincenthbrennsteiner/alphatools_test_data/precursors.tsv already exists
# Creating anndata object from downloaded alphadia data ..
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# File ~/miniconda3/envs/alphaverse/lib/python3.11/site-packages/pandas/core/ops/array_ops.py:218, in _na_arithmetic_op(left, right, op, is_cmp)
#     217 try:
# --> 218     result = func(left, right)
#     219 except TypeError:
#
# File ~/miniconda3/envs/alphaverse/lib/python3.11/site-packages/pandas/core/computation/expressions.py:242, in evaluate(op, a, b, use_numexpr)
#     240     if use_numexpr:
#     241         # error: "None" not callable
# --> 242         return _evaluate(op, op_str, a, b)  # type: ignore[misc]
#     243 return _evaluate_standard(op, op_str, a, b)
#
# File ~/miniconda3/envs/alphaverse/lib/python3.11/site-packages/pandas/core/computation/expressions.py:73, in _evaluate_standard(op, op_str, a, b)
#      72     _store_test_result(False)
# ---> 73 return op(a, b)
#
# File ~/miniconda3/envs/alphaverse/lib/python3.11/site-packages/pandas/core/roperator.py:27, in rtruediv(left, right)
#      26 def rtruediv(left, right):
# ---> 27     return right / left
#
# TypeError: unsupported operand type(s) for /: 'float' and 'str'
#
# During handling of the above exception, another exception occurred:
#
# TypeError                                 Traceback (most recent call last)
# /Users/vincenthbrennsteiner/Documents/mann_labs/_git_repositories/alphatools/notebooks/03b_basic_workflow.ipynb Cell 6 line 3
#       <a href='vscode-notebook-cell:/Users/vincenthbrennsteiner/Documents/mann_labs/_git_repositories/alphatools/notebooks/03b_basic_workflow.ipynb#W5sZmlsZQ%3D%3D?line=0'>1</a> data_handler = DataHandler("domap", target_folder="HOME")
# ----> <a href='vscode-notebook-cell:/Users/vincenthbrennsteiner/Documents/mann_labs/_git_repositories/alphatools/notebooks/03b_basic_workflow.ipynb#W5sZmlsZQ%3D%3D?line=2'>3</a> adata = data_handler.get_data("adata", truncate=_is_pytest_run)
#       <a href='vscode-notebook-cell:/Users/vincenthbrennsteiner/Documents/mann_labs/_git_repositories/alphatools/notebooks/03b_basic_workflow.ipynb#W5sZmlsZQ%3D%3D?line=4'>5</a> df_metadata = data_handler.get_data("metadata")
#       <a href='vscode-notebook-cell:/Users/vincenthbrennsteiner/Documents/mann_labs/_git_repositories/alphatools/notebooks/03b_basic_workflow.ipynb#W5sZmlsZQ%3D%3D?line=5'>6</a> adata = at.pp.add_metadata(adata, df_metadata.set_index("filename"), axis=0, keep_existing_metadata=_is_pytest_run)
#
# File ~/Documents/mann_labs/_git_repositories/alphatools/notebooks/data_handler.py:134, in DataHandler.get_data(self, data_type, truncate, **kwargs)
#     132 if file_format is not None:
#     133     print(f"Creating anndata object from downloaded {file_format} data .. ")
# --> 134     return AnnDataFactory.from_files(file_paths=file_path, reader_type=file_format).create_anndata()
#     136 print("Returning file path to downloaded data .. ")
#     137 return file_path
#
# File ~/Documents/mann_labs/_git_repositories/alphatools/src/alphatools/io/anndata_factory.py:121, in AnnDataFactory.from_files(cls, file_paths, reader_type, intensity_column, protein_id_column, raw_name_column, **kwargs)
#     118 if custom_column_mapping:
#     119     reader.add_column_mapping(custom_column_mapping)
# --> 121 psm_df = reader.load(file_paths)
#     122 return cls(psm_df)
#
# File ~/miniconda3/envs/alphaverse/lib/python3.11/site-packages/alphabase/psm_reader/psm_reader.py:208, in PSMReaderBase.load(self, _file)
#     206 if isinstance(_file, list):
#     207     return self.import_files(_file)
# --> 208 return self.import_file(_file)
#
# File ~/miniconda3/envs/alphaverse/lib/python3.11/site-packages/alphabase/psm_reader/psm_reader.py:249, in PSMReaderBase.import_file(self, _file)
#     247     self._translate_modifications()  # here, sage, msfragger, pfind
#     248     self._filter_fdr()
# --> 249     self._post_process(origin_df)  # here, libraryreader, diann, msfragger
#     250 return self._psm_df
#
# File ~/miniconda3/envs/alphaverse/lib/python3.11/site-packages/alphabase/psm_reader/psm_reader.py:347, in PSMReaderBase._post_process(***failed resolving arguments***)
#     344 reset_precursor_df(self._psm_df)
#     346 if PsmDfCols.PRECURSOR_MZ not in self._psm_df:
# --> 347     self._psm_df = update_precursor_mz(self._psm_df)
#     349 if (
#     350     PsmDfCols.CCS in self._psm_df.columns
#     351     and PsmDfCols.MOBILITY not in self._psm_df.columns
#     352 ):
#     353     self._psm_df[PsmDfCols.MOBILITY] = mobility.ccs_to_mobility_for_df(
#     354         self._psm_df, PsmDfCols.CCS
#     355     )
#
# File ~/miniconda3/envs/alphaverse/lib/python3.11/site-packages/alphabase/peptide/precursor.py:115, in update_precursor_mz(precursor_df, batch_size)
#     110 batch_end = i + batch_size
#     112 df_group = big_df_group.iloc[i:batch_end, :]
#     114 pep_mzs = (
# --> 115     calc_peptide_masses_for_same_len_seqs(
#     116         df_group.sequence.values.astype("U"),
#     117         df_group.mods.values,
#     118         df_group.aa_mass_diffs.values
#     119         if "aa_mass_diffs" in df_group.columns
#     120         else None,
#     121     )
#     122     / df_group.charge
#     123     + MASS_PROTON
#     124 )
#     125 if _calc_in_order:
#     126     precursor_mzs[
#     127         df_group.index.values[0] : df_group.index.values[-1] + 1
#     128     ] = pep_mzs
#
# File ~/miniconda3/envs/alphaverse/lib/python3.11/site-packages/pandas/core/generic.py:2171, in NDFrame.__array_ufunc__(self, ufunc, method, *inputs, **kwargs)
#    2167 @final
#    2168 def __array_ufunc__(
#    2169     self, ufunc: np.ufunc, method: str, *inputs: Any, **kwargs: Any
#    2170 ):
# -> 2171     return arraylike.array_ufunc(self, ufunc, method, *inputs, **kwargs)
#
# File ~/miniconda3/envs/alphaverse/lib/python3.11/site-packages/pandas/core/arraylike.py:276, in array_ufunc(self, ufunc, method, *inputs, **kwargs)
#     273 kwargs = _standardize_out_kwarg(**kwargs)
#     275 # for binary ops, use our custom dunder methods
# --> 276 result = maybe_dispatch_ufunc_to_dunder_op(self, ufunc, method, *inputs, **kwargs)
#     277 if result is not NotImplemented:
#     278     return result
#
# File ops_dispatch.pyx:113, in pandas._libs.ops_dispatch.maybe_dispatch_ufunc_to_dunder_op()
#
# File ~/miniconda3/envs/alphaverse/lib/python3.11/site-packages/pandas/core/ops/common.py:76, in _unpack_zerodim_and_defer.<locals>.new_method(self, other)
#      72             return NotImplemented
#      74 other = item_from_zerodim(other)
# ---> 76 return method(self, other)
#
# File ~/miniconda3/envs/alphaverse/lib/python3.11/site-packages/pandas/core/arraylike.py:214, in OpsMixin.__rtruediv__(self, other)
#     212 @unpack_zerodim_and_defer("__rtruediv__")
#     213 def __rtruediv__(self, other):
# --> 214     return self._arith_method(other, roperator.rtruediv)
#
# File ~/miniconda3/envs/alphaverse/lib/python3.11/site-packages/pandas/core/series.py:6135, in Series._arith_method(self, other, op)
#    6133 def _arith_method(self, other, op):
#    6134     self, other = self._align_for_op(other)
# -> 6135     return base.IndexOpsMixin._arith_method(self, other, op)
#
# File ~/miniconda3/envs/alphaverse/lib/python3.11/site-packages/pandas/core/base.py:1382, in IndexOpsMixin._arith_method(self, other, op)
#    1379     rvalues = np.arange(rvalues.start, rvalues.stop, rvalues.step)
#    1381 with np.errstate(all="ignore"):
# -> 1382     result = ops.arithmetic_op(lvalues, rvalues, op)
#    1384 return self._construct_result(result, name=res_name)
#
# File ~/miniconda3/envs/alphaverse/lib/python3.11/site-packages/pandas/core/ops/array_ops.py:283, in arithmetic_op(left, right, op)
#     279     _bool_arith_check(op, left, right)  # type: ignore[arg-type]
#     281     # error: Argument 1 to "_na_arithmetic_op" has incompatible type
#     282     # "Union[ExtensionArray, ndarray[Any, Any]]"; expected "ndarray[Any, Any]"
# --> 283     res_values = _na_arithmetic_op(left, right, op)  # type: ignore[arg-type]
#     285 return res_values
#
# File ~/miniconda3/envs/alphaverse/lib/python3.11/site-packages/pandas/core/ops/array_ops.py:227, in _na_arithmetic_op(left, right, op, is_cmp)
#     219 except TypeError:
#     220     if not is_cmp and (
#     221         left.dtype == object or getattr(right, "dtype", None) == object
#     222     ):
#    (...)
#     225         # Don't do this for comparisons, as that will handle complex numbers
#     226         #  incorrectly, see GH#32047
# --> 227         result = _masked_arith_op(left, right, op)
#     228     else:
#     229         raise
#
# File ~/miniconda3/envs/alphaverse/lib/python3.11/site-packages/pandas/core/ops/array_ops.py:163, in _masked_arith_op(x, y, op)
#     161     # See GH#5284, GH#5035, GH#19448 for historical reference
#     162     if mask.any():
# --> 163         result[mask] = op(xrav[mask], yrav[mask])
#     165 else:
#     166     if not is_scalar(y):
#
# File ~/miniconda3/envs/alphaverse/lib/python3.11/site-packages/pandas/core/roperator.py:27, in rtruediv(left, right)
#      26 def rtruediv(left, right):
# ---> 27     return right / left
#
# TypeError: unsupported operand type(s) for /: 'float' and 'str'

# %% [markdown]
# ### Filter by data completeness:
#
# Remove features which have more than the allowed fraction of missing values

# %%
# filter out features with more than 25 % missing values
adata = at.pp.filter_data_completeness(
    adata=adata,
    max_missing=0.25,
    axis=1,
)

print("The numeric data in the anndata object:")
display(adata.to_df().head())

print("The sample-level metadata in the anndata object:")
display(adata.obs.head())

print("The feature-level metadata in the anndata object:")
display(adata.var.head())
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /Users/vincenthbrennsteiner/Documents/mann_labs/_git_repositories/alphatools/notebooks/03b_basic_workflow.ipynb Cell 8 line 3
#       <a href='vscode-notebook-cell:/Users/vincenthbrennsteiner/Documents/mann_labs/_git_repositories/alphatools/notebooks/03b_basic_workflow.ipynb#X10sZmlsZQ%3D%3D?line=0'>1</a> # filter out features with more than 25 % missing values
#       <a href='vscode-notebook-cell:/Users/vincenthbrennsteiner/Documents/mann_labs/_git_repositories/alphatools/notebooks/03b_basic_workflow.ipynb#X10sZmlsZQ%3D%3D?line=1'>2</a> adata = at.pp.filter_data_completeness(
# ----> <a href='vscode-notebook-cell:/Users/vincenthbrennsteiner/Documents/mann_labs/_git_repositories/alphatools/notebooks/03b_basic_workflow.ipynb#X10sZmlsZQ%3D%3D?line=2'>3</a>     adata=adata,
#       <a href='vscode-notebook-cell:/Users/vincenthbrennsteiner/Documents/mann_labs/_git_repositories/alphatools/notebooks/03b_basic_workflow.ipynb#X10sZmlsZQ%3D%3D?line=3'>4</a>     max_missing=0.25,
#       <a href='vscode-notebook-cell:/Users/vincenthbrennsteiner/Documents/mann_labs/_git_repositories/alphatools/notebooks/03b_basic_workflow.ipynb#X10sZmlsZQ%3D%3D?line=4'>5</a>     axis=1,
#       <a href='vscode-notebook-cell:/Users/vincenthbrennsteiner/Documents/mann_labs/_git_repositories/alphatools/notebooks/03b_basic_workflow.ipynb#X10sZmlsZQ%3D%3D?line=5'>6</a> )
#       <a href='vscode-notebook-cell:/Users/vincenthbrennsteiner/Documents/mann_labs/_git_repositories/alphatools/notebooks/03b_basic_workflow.ipynb#X10sZmlsZQ%3D%3D?line=7'>8</a> print("The numeric data in the anndata object:")
#       <a href='vscode-notebook-cell:/Users/vincenthbrennsteiner/Documents/mann_labs/_git_repositories/alphatools/notebooks/03b_basic_workflow.ipynb#X10sZmlsZQ%3D%3D?line=8'>9</a> display(adata.to_df().head())
#
# NameError: name 'adata' is not defined

# %% [markdown]
# ### Visualize the distribution of values in different levels of an observational metadata variable
#
# In this example, check the distribution of expression values for a selected protein_id.

# %%
# Apply the AxisManager to make axes iterable and apply consistent AlphaTools styling.
# Axes can also be accessed directly by indexing the axm object.

# create_figure now returns an AxisManager instance
fig, axm = create_figure(nrows=1, ncols=3, figsize=(15, 3))

common_params = {
    "bins": 20,
    "legend": "auto",
    "hist_kwargs": {"alpha": 0.5, "histtype": "stepfilled", "linewidth": 0.5, "edgecolor": "black"},
}

# axm = AxisManager(axs)

# Plot.histogram handles adata natively. Columns from the data and metadata are accessible
# Focus on the distribution of cell types in gene_1
ax = axm.next()

protein_id = "A6NMY6;P07355"
Plots.histogram(data=adata, value_column=protein_id, ax=ax, **common_params)
label_axes(ax, protein_id, "Frequency", f"Distribution of {protein_id}")

# Focus on the distribution of cell types in gene_1
ax = axm.next()
color_column = "replicate"
Plots.histogram(data=adata, value_column=protein_id, color_column=color_column, ax=ax, **common_params)
label_axes(ax, protein_id, "Frequency", f"Distribution of {protein_id} by {color_column}")

# Focus on the distribution of cell types in gene_1
ax = axm.next()
color_column = "fraction"
Plots.histogram(data=adata, value_column=protein_id, color_column=color_column, ax=ax, **common_params)
label_axes(ax, protein_id, "Frequency", f"Distribution of {protein_id} by {color_column}")
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /Users/vincenthbrennsteiner/Documents/mann_labs/_git_repositories/alphatools/notebooks/03b_basic_workflow.ipynb Cell 10 line 2
#      <a href='vscode-notebook-cell:/Users/vincenthbrennsteiner/Documents/mann_labs/_git_repositories/alphatools/notebooks/03b_basic_workflow.ipynb#X12sZmlsZQ%3D%3D?line=16'>17</a> ax = axm.next()
#      <a href='vscode-notebook-cell:/Users/vincenthbrennsteiner/Documents/mann_labs/_git_repositories/alphatools/notebooks/03b_basic_workflow.ipynb#X12sZmlsZQ%3D%3D?line=18'>19</a> protein_id = "A6NMY6;P07355"
# ---> <a href='vscode-notebook-cell:/Users/vincenthbrennsteiner/Documents/mann_labs/_git_repositories/alphatools/notebooks/03b_basic_workflow.ipynb#X12sZmlsZQ%3D%3D?line=19'>20</a> Plots.histogram(data=adata, value_column=protein_id, ax=ax, **common_params)
#      <a href='vscode-notebook-cell:/Users/vincenthbrennsteiner/Documents/mann_labs/_git_repositories/alphatools/notebooks/03b_basic_workflow.ipynb#X12sZmlsZQ%3D%3D?line=20'>21</a> label_axes(ax, protein_id, "Frequency", f"Distribution of {protein_id}")
#      <a href='vscode-notebook-cell:/Users/vincenthbrennsteiner/Documents/mann_labs/_git_repositories/alphatools/notebooks/03b_basic_workflow.ipynb#X12sZmlsZQ%3D%3D?line=22'>23</a> # Focus on the distribution of cell types in gene_1
#
# NameError: name 'adata' is not defined
