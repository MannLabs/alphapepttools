# %% [markdown]
# # Example of multi-omics integration with AlphaPeptTools

# %% [markdown]
# ## Example dataset: Pancreatic Islet study with proteomics and RNAseq data

# %% [markdown]
# Study [1]
#
# [1]: Thielert, Marvin, et al. "Decoding adult murine pancreatic islet cell diversity through cell type-resolved proteomics and phosphoproteomics." Communications Biology 8.1 (2025): 1483.

# %%
import logging

logger = logging.getLogger(__name__)
